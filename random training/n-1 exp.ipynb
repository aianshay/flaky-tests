# %%
import pandas as pd

# %%
msr_data = pd.read_csv('msr/msr_data.csv')
new_data = pd.read_csv('new/new_data.csv')

# %%
msr_data.groupby(['project','flaky'])['flaky'].agg({'quantity':'count'})
# Out:
# c:\users\aian\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.
#                     quantity
# project      flaky
# achilles     1            67
# alluxio      1             4
# ambari       1             4
# commons-exec 1             2
# dropwizard   1             1
# hadoop       0           756
#              1           305
# handlebars   1             1
# hector       1             2
# httpcore     0           296
#              1             2
# jackrabbit   1             8
# jimfs        1             7
# logback      0            90
#              1             3
# ninja        0           172
#              1            18
# okhttp       1            66
# oozie        1           857
# orbit        1             8
# oryx         1            13
# spring-boot  1            14
# togglz       1            11
# wroj4        1            10
# zxing        0            88
#              1             1

# %%
new_data.groupby(['project','flaky'])['flaky'].agg({'quantity':'count'})
# Out:
# c:\users\aian\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.
#                     quantity
# project      flaky
# achilles     0             4
#              1             4
# activiti     0            32
#              1            32
# alluxio      0            71
#              1           116
# ambari       0            52
#              1            52
# assertjcore  0             1
#              1             1
# commons-exec 0            45
# dubbo        0            19
#              1            19
# elasticjob   0             3
#              1             3
# hadoop       0           145
#              1           145
# handlebars   0             1
#              1             1
# hector       0            33
#              1            33
# http-request 0            18
#              1            18
# httpcore     0            22
#              1            22
# jackrabbit   0             8
#              1             8
# logback      0            22
#              1            22
# ninja        0             1
#              1             1
# okhttp       0           100
#              1           100
# orbit        0             7
#              1             7
# spring-boot  0           160
#              1           160
# togglz       0             1
#              1             1
# undertow     0             7
#              1             7
# websocket    0            23
#              1            23
# wildfly      0            23
#              1            23
# wroj4        0            16
#              1            16
# zxing        0             2
#              1             2

# %%
new_data.query('project == "spring-boot"')
# Out:
#                                                   token      project  flaky
# 1     repackage-sources.jar.original forTasks BOOT_V...  spring-boot      1
# 3     Wrong body:   spring-boot-actuator getForObjec...  spring-boot      0
# 7     next getClass values redisHealthIndicator refr...  spring-boot      0
# 8     forTasks BOOT_VERSION install -PbootVersion= i...  spring-boot      1
# 9     assertOutputMatches forTasks BOOT_VERSION -jav...  spring-boot      1
# ...                                                 ...          ...    ...
# 1619  checkSpring oldSpringModulesAreNotTransitiveDe...  spring-boot      1
# 1623  EnvironmentTestUtils myid .id:myid addEnvironm...  spring-boot      0
# 1627  checkCommonsLogging runBuildForTask commonsLog...  spring-boot      1
# 1628  result size assertTrue get invoke assertEquals...  spring-boot      0
# 1631  checkSpring oldSpringModulesAreNotTransitiveDe...  spring-boot      1
#
# [320 rows x 3 columns]

# %%
msr_data.head()
# Out:
#                                                token   project  flaky
# 0   call testResourceGetPostParamGet POST MyJsonR...     oozie      1
# 1  cluster createTable getClusterStatus hcd TEST_...    hadoop      1
# 2  fail testSetMaxInvalid Assert setDefaultMaxPer...  httpcore      0
# 3   thinks that it is single rack assertSingleSwi...    hadoop      0
# 4  hcatUri2  checkCoordAction CoordELFunctions hc...     oozie      1

# %%
new_data.head()
# Out:
#                                                token      project  flaky
# 0  process testFolder forEachFileInFolder apply g...        wroj4      1
# 1  repackage-sources.jar.original forTasks BOOT_V...  spring-boot      1
# 2  add next controller assertFalse testGetActions...       ambari      1
# 3  Wrong body:   spring-boot-actuator getForObjec...  spring-boot      0
# 4  createTimerJobQuery createTaskQuery createProc...     activiti      1

# %%
msr_data['project'].value_counts()
# Out:
# hadoop          1061
# oozie            857
# httpcore         298
# ninja            190
# logback           93
# zxing             89
# achilles          67
# okhttp            66
# spring-boot       14
# oryx              13
# togglz            11
# wroj4             10
# jackrabbit         8
# orbit              8
# jimfs              7
# alluxio            4
# ambari             4
# hector             2
# commons-exec       2
# handlebars         1
# dropwizard         1
# Name: project, dtype: int64

# %%
new_data['project'].value_counts()
# Out:
# spring-boot     320
# hadoop          290
# okhttp          200
# alluxio         187
# ambari          104
# hector           66
# activiti         64
# wildfly          46
# websocket        46
# commons-exec     45
# logback          44
# httpcore         44
# dubbo            38
# http-request     36
# wroj4            32
# jackrabbit       16
# undertow         14
# orbit            14
# achilles          8
# elasticjob        6
# zxing             4
# togglz            2
# handlebars        2
# ninja             2
# assertjcore       2
# Name: project, dtype: int64

# %%
msr_proj = msr_data['project'].unique()
print('msr projects', msr_proj)
print('total', len(msr_proj))
# Out:
# msr projects ['oozie' 'hadoop' 'httpcore' 'ambari' 'oryx' 'ninja' 'zxing' 'jimfs'
#  'logback' 'spring-boot' 'achilles' 'okhttp' 'orbit' 'togglz'
#  'commons-exec' 'wroj4' 'alluxio' 'hector' 'jackrabbit' 'handlebars'
#  'dropwizard']
# total 21

# %%
new_proj = new_data['project'].unique()
print('new projects', new_proj)
print('total', len(new_proj))
# Out:
# new projects ['wroj4' 'spring-boot' 'ambari' 'activiti' 'ninja' 'orbit' 'assertjcore'
#  'elasticjob' 'commons-exec' 'websocket' 'alluxio' 'hadoop' 'dubbo'
#  'okhttp' 'httpcore' 'hector' 'logback' 'wildfly' 'togglz' 'zxing'
#  'http-request' 'jackrabbit' 'achilles' 'undertow' 'handlebars']
# total 25

# %%
intersection = list(set(new_proj).intersection(msr_proj))
print(intersection)
print('total', len(intersection))
# Out:
# ['ambari', 'ninja', 'handlebars', 'hadoop', 'orbit', 'achilles', 'logback', 'zxing', 'togglz', 'httpcore', 'wroj4', 'alluxio', 'jackrabbit', 'spring-boot', 'okhttp', 'commons-exec', 'hector']
# total 17

# %%
msr_data.shape
# Out:
# (2806, 3)

# %%
msr_no_duplicates = msr_data.drop_duplicates()
msr_no_duplicates.shape
# Out:
# (2771, 3)

# %%
new_data.shape
# Out:
# (1632, 3)

# %%
new_no_duplicates = new_data.drop_duplicates()
new_no_duplicates.shape
# Out:
# (1464, 3)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.linear_model import SGDClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, f1_score
import pandas as pd

# %% [markdown]
# ### Training naive bayes model on MSR data

# %%
from sklearn.metrics import accuracy_score

def run_exp(data):
    if data == 'msr':
        exp_data = msr_no_duplicates
    elif data == 'new':
        exp_data = new_no_duplicates
        
    list_of_projects = exp_data['project'].unique()
    print('project list:', list_of_projects, end='\n\n')
    
    for project in list_of_projects:
        print('selected project:', project)

        train_data = exp_data.query(f'project != "{project}"')    
        X_train = train_data['token'].values.astype('U')
        y_train = train_data['flaky']

        text_clf1 = Pipeline([
            ('vectorizer', CountVectorizer()),
            ('model', MultinomialNB())])
        text_clf1.fit(X_train, y_train)

        test_data = exp_data.query(f'project == "{project}"') 
        X_test = test_data['token'].values.astype('U')
        y_test = test_data['flaky']

        new_preds = text_clf1.predict(X_test)
        #accuracy = accuracy_score(y_test, new_preds)
        #f1 = f1_score(y_test, new_preds)        
        #print('accuracy: {0:.2f} ----- f1 {1:.2f}'.format(accuracy, f1), end="\n\n")
        print(classification_report(y_test, new_preds, zero_division=0))

# %%
run_exp(data='msr')
# Out:
# project list: ['oozie' 'hadoop' 'httpcore' 'ambari' 'oryx' 'ninja' 'zxing' 'jimfs'
#  'logback' 'spring-boot' 'achilles' 'okhttp' 'orbit' 'togglz'
#  'commons-exec' 'wroj4' 'alluxio' 'hector' 'jackrabbit' 'handlebars'
#  'dropwizard']
#
# selected project: oozie
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.30      0.47       845
#
#     accuracy                           0.30       845
#    macro avg       0.50      0.15      0.23       845
# weighted avg       1.00      0.30      0.47       845
#
# selected project: hadoop
#               precision    recall  f1-score   support
#
#            0       0.79      0.47      0.59       756
#            1       0.34      0.69      0.46       305
#
#     accuracy                           0.53      1061
#    macro avg       0.57      0.58      0.52      1061
# weighted avg       0.66      0.53      0.55      1061
#
# selected project: httpcore
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95       283
#            1       0.04      0.50      0.07         2
#
#     accuracy                           0.91       285
#    macro avg       0.52      0.71      0.51       285
# weighted avg       0.99      0.91      0.95       285
#
# selected project: ambari
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       0.0
#            1       0.00      0.00      0.00       4.0
#
#     accuracy                           0.00       4.0
#    macro avg       0.00      0.00      0.00       4.0
# weighted avg       0.00      0.00      0.00       4.0
#
# selected project: oryx
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.15      0.27        13
#
#     accuracy                           0.15        13
#    macro avg       0.50      0.08      0.13        13
# weighted avg       1.00      0.15      0.27        13
#
# selected project: ninja
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91       171
#            1       0.00      0.00      0.00        18
#
#     accuracy                           0.84       189
#    macro avg       0.45      0.46      0.46       189
# weighted avg       0.81      0.84      0.83       189
#
# selected project: zxing
#               precision    recall  f1-score   support
#
#            0       0.98      0.72      0.83        88
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.71        89
#    macro avg       0.49      0.36      0.41        89
# weighted avg       0.97      0.71      0.82        89
#
# selected project: jimfs
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       0.0
#            1       0.00      0.00      0.00       5.0
#
#     accuracy                           0.00       5.0
#    macro avg       0.00      0.00      0.00       5.0
# weighted avg       0.00      0.00      0.00       5.0
#
# selected project: logback
#               precision    recall  f1-score   support
#
#            0       0.97      0.69      0.81        90
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.67        92
#    macro avg       0.48      0.34      0.40        92
# weighted avg       0.95      0.67      0.79        92
#
# selected project: spring-boot
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.36      0.53        14
#
#     accuracy                           0.36        14
#    macro avg       0.50      0.18      0.26        14
# weighted avg       1.00      0.36      0.53        14
#
# selected project: achilles
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.01      0.03        67
#
#     accuracy                           0.01        67
#    macro avg       0.50      0.01      0.01        67
# weighted avg       1.00      0.01      0.03        67
#
# selected project: okhttp
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.02      0.03        60
#
#     accuracy                           0.02        60
#    macro avg       0.50      0.01      0.02        60
# weighted avg       1.00      0.02      0.03        60
#
# selected project: orbit
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       0.0
#            1       0.00      0.00      0.00       8.0
#
#     accuracy                           0.00       8.0
#    macro avg       0.00      0.00      0.00       8.0
# weighted avg       0.00      0.00      0.00       8.0
#
# selected project: togglz
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.27      0.43        11
#
#     accuracy                           0.27        11
#    macro avg       0.50      0.14      0.21        11
# weighted avg       1.00      0.27      0.43        11
#
# selected project: commons-exec
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       0.0
#            1       0.00      0.00      0.00       2.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
#
# selected project: wroj4
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       0.0
#            1       0.00      0.00      0.00      10.0
#
#     accuracy                           0.00      10.0
#    macro avg       0.00      0.00      0.00      10.0
# weighted avg       0.00      0.00      0.00      10.0
#
# selected project: alluxio
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       0.0
#            1       0.00      0.00      0.00       4.0
#
#     accuracy                           0.00       4.0
#    macro avg       0.00      0.00      0.00       4.0
# weighted avg       0.00      0.00      0.00       4.0
#
# selected project: hector
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
# selected project: jackrabbit
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.25      0.40         8
#
#     accuracy                           0.25         8
#    macro avg       0.50      0.12      0.20         8
# weighted avg       1.00      0.25      0.40         8
#
# selected project: handlebars
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         1
#    macro avg       1.00      1.00      1.00         1
# weighted avg       1.00      1.00      1.00         1
#
# selected project: dropwizard
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       0.0
#            1       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       1.0
#    macro avg       0.00      0.00      0.00       1.0
# weighted avg       0.00      0.00      0.00       1.0

# %%
run_exp(data='new')
# Out:
# project list: ['wroj4' 'spring-boot' 'ambari' 'activiti' 'ninja' 'orbit' 'assertjcore'
#  'elasticjob' 'commons-exec' 'websocket' 'alluxio' 'hadoop' 'dubbo'
#  'okhttp' 'httpcore' 'hector' 'logback' 'wildfly' 'togglz' 'zxing'
#  'http-request' 'jackrabbit' 'achilles' 'undertow' 'handlebars']
#
# selected project: wroj4
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.82        16
#            1       0.86      0.75      0.80        16
#
#     accuracy                           0.81        32
#    macro avg       0.82      0.81      0.81        32
# weighted avg       0.82      0.81      0.81        32
#
# selected project: spring-boot
#               precision    recall  f1-score   support
#
#            0       0.48      0.39      0.43       136
#            1       0.24      0.31      0.27        84
#
#     accuracy                           0.36       220
#    macro avg       0.36      0.35      0.35       220
# weighted avg       0.39      0.36      0.37       220
#
# selected project: ambari
#               precision    recall  f1-score   support
#
#            0       0.44      0.63      0.52        52
#            1       0.34      0.19      0.25        52
#
#     accuracy                           0.41       104
#    macro avg       0.39      0.41      0.38       104
# weighted avg       0.39      0.41      0.38       104
#
# selected project: activiti
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         4
#            1       0.97      0.97      0.97        32
#
#     accuracy                           0.94        36
#    macro avg       0.86      0.86      0.86        36
# weighted avg       0.94      0.94      0.94        36
#
# selected project: ninja
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
# selected project: orbit
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         6
#            1       0.64      1.00      0.78         7
#
#     accuracy                           0.69        13
#    macro avg       0.82      0.67      0.64        13
# weighted avg       0.80      0.69      0.65        13
#
# selected project: assertjcore
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
# selected project: elasticjob
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         3
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.83         6
#    macro avg       0.88      0.83      0.83         6
# weighted avg       0.88      0.83      0.83         6
#
# selected project: commons-exec
#               precision    recall  f1-score   support
#
#            0       1.00      0.76      0.86        45
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.76        45
#    macro avg       0.50      0.38      0.43        45
# weighted avg       1.00      0.76      0.86        45
#
# selected project: websocket
#               precision    recall  f1-score   support
#
#            0       0.42      0.74      0.54        23
#            1       0.00      0.00      0.00        23
#
#     accuracy                           0.37        46
#    macro avg       0.21      0.37      0.27        46
# weighted avg       0.21      0.37      0.27        46
#
# selected project: alluxio
#               precision    recall  f1-score   support
#
#            0       0.51      0.57      0.54        56
#            1       0.77      0.73      0.75       113
#
#     accuracy                           0.67       169
#    macro avg       0.64      0.65      0.64       169
# weighted avg       0.69      0.67      0.68       169
#
# selected project: hadoop
#               precision    recall  f1-score   support
#
#            0       0.46      0.24      0.32       145
#            1       0.47      0.71      0.57       140
#
#     accuracy                           0.47       285
#    macro avg       0.47      0.47      0.44       285
# weighted avg       0.47      0.47      0.44       285
#
# selected project: dubbo
#               precision    recall  f1-score   support
#
#            0       0.25      0.71      0.37         7
#            1       0.67      0.21      0.32        19
#
#     accuracy                           0.35        26
#    macro avg       0.46      0.46      0.35        26
# weighted avg       0.55      0.35      0.33        26
#
# selected project: okhttp
#               precision    recall  f1-score   support
#
#            0       0.44      0.41      0.42       100
#            1       0.45      0.48      0.46       100
#
#     accuracy                           0.45       200
#    macro avg       0.44      0.44      0.44       200
# weighted avg       0.44      0.45      0.44       200
#
# selected project: httpcore
#               precision    recall  f1-score   support
#
#            0       0.58      0.64      0.61        22
#            1       0.58      0.52      0.55        21
#
#     accuracy                           0.58        43
#    macro avg       0.58      0.58      0.58        43
# weighted avg       0.58      0.58      0.58        43
#
# selected project: hector
#               precision    recall  f1-score   support
#
#            0       0.55      0.72      0.62        32
#            1       0.61      0.42      0.50        33
#
#     accuracy                           0.57        65
#    macro avg       0.58      0.57      0.56        65
# weighted avg       0.58      0.57      0.56        65
#
# selected project: logback
#               precision    recall  f1-score   support
#
#            0       0.56      0.41      0.47        22
#            1       0.54      0.68      0.60        22
#
#     accuracy                           0.55        44
#    macro avg       0.55      0.55      0.54        44
# weighted avg       0.55      0.55      0.54        44
#
# selected project: wildfly
#               precision    recall  f1-score   support
#
#            0       0.62      0.91      0.74        23
#            1       0.83      0.43      0.57        23
#
#     accuracy                           0.67        46
#    macro avg       0.73      0.67      0.65        46
# weighted avg       0.73      0.67      0.65        46
#
# selected project: togglz
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
# selected project: zxing
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       1.00      0.50      0.67         2
#
#     accuracy                           0.67         3
#    macro avg       0.75      0.75      0.67         3
# weighted avg       0.83      0.67      0.67         3
#
# selected project: http-request
#               precision    recall  f1-score   support
#
#            0       0.49      0.94      0.64        18
#            1       0.00      0.00      0.00        18
#
#     accuracy                           0.47        36
#    macro avg       0.24      0.47      0.32        36
# weighted avg       0.24      0.47      0.32        36
#
# selected project: jackrabbit
#               precision    recall  f1-score   support
#
#            0       0.45      0.62      0.53         8
#            1       0.40      0.25      0.31         8
#
#     accuracy                           0.44        16
#    macro avg       0.43      0.44      0.42        16
# weighted avg       0.43      0.44      0.42        16
#
# selected project: achilles
#               precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67         4
#            1       0.67      0.50      0.57         4
#
#     accuracy                           0.62         8
#    macro avg       0.63      0.62      0.62         8
# weighted avg       0.63      0.62      0.62         8
#
# selected project: undertow
#               precision    recall  f1-score   support
#
#            0       0.50      0.57      0.53         7
#            1       0.40      0.33      0.36         6
#
#     accuracy                           0.46        13
#    macro avg       0.45      0.45      0.45        13
# weighted avg       0.45      0.46      0.46        13
#
# selected project: handlebars
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
